# %%
import csv
from pathlib import Path

menu_filepath = Path('menu_data.csv')
sales_filepath = Path('sales_data.csv')

menu = []
sales = []

with open(menu_filepath, 'r') as menu_file:
    menuread = csv.reader(menu_file)
    menu_header = next(menuread)
    for i in menuread:
        menu.append(i)

with open(sales_filepath, 'r') as sales_file:
    salesread = csv.reader(sales_file)
    next(salesread)
    for i in salesread:
        sales.append(i)

# @TODO: Initialize dict object to hold our key-value pairs of items and metrics
report = {
    'sales_item':{
        
    }
}

row_count = 0

# @TODO: Loop over every row in the sales list object
quantity=[]
menu_item=[]
item = []
price=[]
cost=[]
for i in sales:
    quantity.append(int(i[3]))
    menu_item.append(i[4])
    sales_item = {
        '01-count':0,
        '02-revenue':0,
        '03-cogs':0,
        '04-profit':0,
    }
    
    for row in menu:
        item.append(row[0])
        price.append(row[3])
        cost.append(row[4])
        if menu_item == item:
            report[sales_item]['01-count'] += quantity
            report[sales_item]["02-revenue"] += price * quantity
            report[sales_item]["03-cogs"] += cost * quantity
            report[sales_item]["04-profit"] += profit * quantity
        else:
            print(F"{sales_item} does not equal {item}! NO MATCH!")
    row_counter +=1


# @TODO: Print total number of records in sales data
print(row_counter)



# @TODO: Write out report to a text file (won't appear on the command line output)
